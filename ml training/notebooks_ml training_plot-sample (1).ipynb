# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

#radius_mean	texture_mean
x_b = [14.59, 11.51, 14.05, 11.2]
y_b = [22.68, 23.93, 27.15, 29.37]
plt.xlim(5, 35)
plt.ylim(5, 35)
plt.grid()
plt.xlabel('radius_mean', fontsize=10)
plt.ylabel('texture_mean', fontsize=10)

#Plot b cells
plt.scatter(x_b, y_b, marker=".", color="red", label='Malign')
plt.legend()


#Plot m cells
x_m = [15.22, 20.92, 21.56, 20.13]
y_m = [30.62, 25.09, 22.39, 28.25]
plt.scatter(x_m, y_m, marker=".", color="blue", label='Benign')
plt.legend(numpoints=1)


#B
x_test = [7.76]
y_test = [24.54]
plt.scatter(x_test, y_test, marker=".", color="purple", label='To be determined')
plt.legend(numpoints=1)

#plt.show()

font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 12,
        }
plt.text(7, 10, r'$R_1: M=radius\_mean<15$', fontdict=font)
plt.text(7, 6, r'$R_2: M = texture\_mean <30$', fontdict=font)



plt.show()
