# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
x_b = [14.59, 11.51, 14.05, 11.2]
y_b = [22.68, 23.93, 27.15, 29.37]
plt.xlim(5, 35)
plt.ylim(5, 35)
plt.grid()
for index in range(len(x_b)):
    plt.plot(x_b[index], y_b[index], marker=".", markersize=10, markeredgecolor="red", markerfacecolor="red", label='Malign')
plt.legend()

x_m = [15.22, 20.92, 21.56, 20.13]
y_m = [30.62, 25.09, 22.39, 28.25]

for index in range(len(x_m)):
    plt.plot(x_m[index], y_m[index], marker=".", markersize=10, markeredgecolor="blue", markerfacecolor="blue", label='Benign')
plt.legend(numpoints=1)


#B
x_test = [7.76]
y_test = [24.54]
plt.plot(x_test, y_test, marker=".", markersize=10, markeredgecolor="purple", markerfacecolor="purple", label='To be determined')
plt.legend(numpoints=1)

plt.show()
